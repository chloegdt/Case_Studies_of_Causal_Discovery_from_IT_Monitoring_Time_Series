# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
antivirus_activity = pd.read_csv('data/Antivirus_Activity/preprocessed_1.csv', parse_dates=True) 
antivirus_activity['timestamp'] = pd.to_datetime(antivirus_activity['timestamp'])
antivirus_activity = antivirus_activity.set_index('timestamp')
antivirus_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1320 entries, 2023-04-06 15:00:00 to 2023-04-11 04:55:00
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   memory_usage_Portal               1320 non-null   float64
#  1   cpu_usage_Portal                  1320 non-null   float64
#  2   Physical_Memory_prct_used_Portal  1320 non-null   float64
#  3   cpu_prct_used_Portal              1320 non-null   float64
#  4   0_C_read_Portal                   1320 non-null   float64
#  5   memory_usage_VDI                  1320 non-null   float64
#  6   cpu_usage_VDI                     1320 non-null   float64
#  7   Physical_Memory_prct_used_VDI     1320 non-null   float64
#  8   cpu_prct_used_VDI                 1320 non-null   float64
#  9   0_C_read_VDI                      1320 non-null   float64
#  10  Chargement_portail                1320 non-null   float64
# ...

# %%
axes = antivirus_activity[['memory_usage_Portal', 
                           'cpu_usage_Portal', 
                           'Physical_Memory_prct_used_Portal']].plot(subplots=True);
